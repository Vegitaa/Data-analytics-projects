# %%
df=pd.read_csv('/content/Train.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df.isna().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

imputer.fit(df['Family_Size'].values.reshape(-1,1))
df['Family_Size']=imputer.fit_transform(df['Family_Size'].values.reshape(-1,1))




imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer.fit(df['Work_Experience'].values.reshape(-1,1))
df['Work_Experience']=imputer.fit_transform(df['Work_Experience'].values.reshape(-1,1))

imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer.fit(df['Profession'].values.reshape(-1,1))
df['Profession']=imputer.fit_transform(df['Profession'].values.reshape(-1,1))

imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer.fit(df['Graduated'].values.reshape(-1,1))
df['Graduated']=imputer.fit_transform(df['Graduated'].values.reshape(-1,1))

imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer.fit(df['Ever_Married'].values.reshape(-1,1))
df['Ever_Married']=imputer.fit_transform(df['Ever_Married'].values.reshape(-1,1))

imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer.fit(df['Var_1'].values.reshape(-1,1))
df['Var_1']=imputer.fit_transform(df['Var_1'].values.reshape(-1,1))


df.head(20)
# Out:
#         ID  Gender Ever_Married  Age Graduated     Profession  \
# 0   462809    Male           No   22        No     Healthcare
# 1   462643  Female          Yes   38       Yes       Engineer
# 2   466315  Female          Yes   67       Yes       Engineer
# 3   461735    Male          Yes   67       Yes         Lawyer
# 4   462669  Female          Yes   40       Yes  Entertainment
# 5   461319    Male          Yes   56        No         Artist
# 6   460156    Male           No   32       Yes     Healthcare
# 7   464347  Female           No   33       Yes     Healthcare
# 8   465015  Female          Yes   61       Yes       Engineer
# 9   465176  Female          Yes   55       Yes         Artist
# 10  464041  Female           No   26       Yes       Engineer
# 11  464942    Male           No   19        No     Healthcare
# 12  461230  Female           No   19        No      Executive
# 13  459573    Male          Yes   70        No         Lawyer
# ...

# %%
df.isna().sum()
# Out:
# ID                 0
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
#df['Work_Experience'] = df['Work_Experience'].astype('int')
plt.boxplot(df['Work_Experience'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7933844f1bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7933844f0f40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7933844f0f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7933844f0040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7933844f3400>],
#  'means': []}

# %%
def removeouliers(col):
  quant1,quant2=col.quantile([0.25,0.75])
  IQR=quant2-quant1
  lower_range=quant1-(1.5*IQR)
  upper_range=quant2+(1.5*IQR)
  return lower_range,upper_range

# %%
lowscore,highscore=removeouliers(df['Work_Experience'])
df['Work_Experience']=np.where(df['Work_Experience']>highscore,highscore,df['Work_Experience'])
df['Work_Experience']=np.where(df['Work_Experience']<lowscore,lowscore,df['Work_Experience'])

# %%
plt.boxplot(df['Work_Experience']);

# %%
plt.boxplot(df['Age'])
lowscore,highscore=removeouliers(df['Age'])
df['Age']=np.where(df['Age']>highscore,highscore,df['Age'])
df['Age']=np.where(df['Age']<lowscore,lowscore,df['Age'])
#plt.boxplot(df['Age'])

# %%
lowscore,highscore=removeouliers(df['Family_Size'])
df['Family_Size']=np.where(df['Family_Size']>highscore,highscore,df['Family_Size'])
df['Family_Size']=np.where(df['Family_Size']<lowscore,lowscore,df['Family_Size'])
plt.boxplot(df['Family_Size']);

# %%
x=df.iloc[:,1:9]
y=df.iloc[:,-1]

# %%
X=pd.get_dummies(x)

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
XX=std.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=5)
XXX=pca.fit_transform(XX)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(XXX,y,test_size=0.3,random_state=20)

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(n_estimators=100).fit(xtrain,ytrain)

# %%
pred=bag_model.predict(xtest)

# %%
from sklearn.metrics import classification_report,confusion_matrix
report=classification_report(pred,ytest)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            A       0.34      0.36      0.35       566
#            B       0.32      0.35      0.33       522
#            C       0.50      0.48      0.49       610
#            D       0.64      0.60      0.62       723
#
#     accuracy                           0.46      2421
#    macro avg       0.45      0.45      0.45      2421
# weighted avg       0.47      0.46      0.46      2421

# %%
import seaborn as sns
#Bagging Meta Estimator Classifier
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression
#making the bagging classifier with 100 Logistic Regression models
model=BaggingClassifier(base_estimator=LogisticRegression(),n_estimators=100)
#fitting data to bagging model
model.fit(xtrain,ytrain)
#testing on test dataset
ypred=model.predict(xtest)
#Model Evaluation
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print("accuracy is :",accuracy_score(ytest,ypred))
cm=confusion_matrix(ytest,ypred)
sns.heatmap(cm,annot=True)
print(classification_report(ytest,ypred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# accuracy is : 0.4758364312267658
#               precision    recall  f1-score   support
#
#            A       0.41      0.45      0.43       586
#            B       0.36      0.09      0.14       574
#            C       0.43      0.64      0.51       585
#            D       0.61      0.68      0.64       676
#
#     accuracy                           0.48      2421
#    macro avg       0.45      0.47      0.43      2421
# weighted avg       0.46      0.48      0.44      2421

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(xtrain, ytrain)
ypred=model.predict(xtest)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Accuracy is :",accuracy_score(ytest,ypred))
print(classification_report(ytest,ypred))
cm=confusion_matrix(ytest,ypred)
cm
sns.heatmap(cm,annot=True)
# Out:
# Accuracy is : 0.5051631557207765
#               precision    recall  f1-score   support
#
#            A       0.42      0.40      0.41       586
#            B       0.38      0.33      0.35       574
#            C       0.54      0.55      0.54       585
#            D       0.63      0.71      0.66       676
#
#     accuracy                           0.51      2421
#    macro avg       0.49      0.50      0.49      2421
# weighted avg       0.50      0.51      0.50      2421
# <Axes: >

# %%
from sklearn.ensemble import AdaBoostClassifier
model_1 = AdaBoostClassifier(random_state=1)
model_1.fit(xtrain, ytrain)
ypred=model_1.predict(xtest)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Accuracy is :",accuracy_score(ytest,ypred))
print(classification_report(ytest,ypred))
cm=confusion_matrix(ytest,ypred)
cm
sns.heatmap(cm,annot=True)
# Out:
# Accuracy is : 0.4993804213135068
#               precision    recall  f1-score   support
#
#            A       0.41      0.47      0.44       586
#            B       0.38      0.26      0.31       574
#            C       0.54      0.55      0.54       585
#            D       0.61      0.68      0.64       676
#
#     accuracy                           0.50      2421
#    macro avg       0.48      0.49      0.48      2421
# weighted avg       0.49      0.50      0.49      2421
# <Axes: >
